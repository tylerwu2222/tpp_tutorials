# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# #### beautifulsoup, multipage example

# %%
# get cast
# first get href (link) to cast
url = 'https://www.imdb.com/chart/moviemeter'
request = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
print(request.content)
# print(request)
soup = BeautifulSoup(request.content,'html.parser')
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        \n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);\n\n\n    var ue_err_chan = \'jserr\';\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=""+(e.location?e.location.href:"");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:""+e,err:g,fromOnError:1,args:arguments},g?{attribution:g.attribution,logLevel:g.logLevel}:void 0);return!1}var k="FATAL",m="ERROR",n="WARN",p="DOWNGRADED",a={ec:0,ecf:0,\npec:0,ts:0,erl:[],ter:[],buffer:[],mxe:50,startTimer:function(){a.ts++;setInterval(function(){d.ue&&a.pec<a.ec&&d.uex("at");a.pec=a.ec},1E4)}};l.skipTrace=1;h.skipTrace=1;h.isStub=1;d.ueLogError=h;d.ue_err=a;e.onerror=l})(ue_csm,window);\n\n\nvar ue_id = \'20E3T5ED5BJ2CG8E8DG1\',\n    ue_url,\n    ue_navtiming = 1,\n    ue_mid = \'A1EVAM02EL8SFB\',\n    ue_sid = \'145-1144089-7451359\',\n    ue_sn = \'www.imdb.com\',\n    ue_furl = \'fls-na.amazon.com\',\n    ue_surl = \'https://unagi-na.amazon.com/1/events/com.amazon.csm.nexusclient.prod\',\n    ue_int = 0,\n    ue_fcsn = 1,\n    ue_urt = 3,\n    ue_rpl_ns = \'cel-rpl\',\n    ue_ddq = 1,\n    ue_fpf = \'//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:145-1144089-7451359:20E3T5ED5BJ2CG8E8DG1$uedata=s:\',\n    ue_sbuimp = 1,\n    ue_ibft = 0,\n    ue_sswmts = 0,\n    ue_jsmtf = 0,\n    ue_fnt = 0,\n    ue_lpsi = 6000,\n    ue_no_counters = 0,\n\n    ue_swi = 1;\nvar ue_viz=function(){(function(b,e,a){function k(c){if(b.ue.viz.length<p&&!l){var a=c.type;c=c.originalEvent;/^focus./.test(a)&&c&&(c.toElement||c.fromElement||c.relatedTarget)||(a=e[m]||("blur"==a||"focusout"==a?"hidden":"visible"),b.ue.viz.push(a+":"+(+new Date-b.ue.t0)),"visible"==a&&(b.ue.isl&&q("at"),l=1))}}for(var l=0,q=b.uex,f,g,m,n=["","webkit","o","ms","moz"],d=0,p=20,h=0;h<n.length&&!d;h++)if(a=n[h],f=(a?a+"H":"h")+"idden",d="boolean"==typeof e[f])g=a+"visibilitychange",m=(a?a+"V":"v")+\n"isibilityState";k({});d&&e.addEventListener(g,k,0);b.ue&&d&&(b.ue.pageViz={event:g,propHid:f})})(ue_csm,ue_csm.document,ue_csm.window)};\n\n(function(d,h,N){function H(a){return a&&a.replace&&a.replace(/^\\s+|\\s+$/g,"")}function u(a){return"undefined"===typeof a}function B(a,b){for(var c in b)b[v](c)&&(a[c]=b[c])}function I(a){try{var b=N.cookie.match(RegExp("(^| )"+a+"=([^;]+)"));if(b)return b[2].trim()}catch(c){}}function O(k,b,c){var q=(x||{}).type;if("device"!==c||2!==q&&1!==q)k&&(d.ue_id=a.id=a.rid=k,w&&(w=w.replace(/((.*?:){2})(\\w+)/,function(a,b){return b+k})),D&&(e("id",D,k),D=0)),b&&(w&&(w=w.replace(/(.*?:)(\\w|-)+/,function(a,\nc){return c+b})),d.ue_sid=b),c&&a.tag("page-source:"+c),d.ue_fpf=w}function P(){var a={};return function(b){b&&(a[b]=1);b=[];for(var c in a)a[v](c)&&b.push(c);return b}}function y(d,b,c,q){q=q||+new E;var f,m;if(b||u(c)){if(d)for(m in f=b?e("t",b)||e("t",b,{}):a.t,f[d]=q,c)c[v](m)&&e(m,b,c[m]);return q}}function e(d,b,c){var e=b&&b!=a.id?a.sc[b]:a;e||(e=a.sc[b]={});"id"===d&&c&&(Q=1);return e[d]=c||e[d]}function R(d,b,c,e,f){c="on"+c;var m=b[c];"function"===typeof m?d&&(a.h[d]=m):m=function(){};b[c]=\nfunction(a){f?(e(a),m(a) ...

# %%
print(soup.find('table').prettify())
# Out:
# <table class="chart full-width" data-caller-name="chart-moviemeter">
#  <colgroup>
#   <col class="chartTableColumnPoster"/>
#   <col class="chartTableColumnTitle"/>
#   <col class="chartTableColumnIMDbRating"/>
#   <col class="chartTableColumnYourRating"/>
#   <col class="chartTableColumnWatchlistRibbon"/>
#  </colgroup>
#  <thead>
#   <tr>
#    <th>
#    </th>
#    <th>
#     Rank &amp; Title
#    </th>
#    <th>
#     IMDb Rating
#    </th>
#    <th>
#     Your Rating
#    </th>
#    <th>
#    </th>
#   </tr>
#  </thead>
#  <tbody class="lister-list">
#   <tr>
#    <td class="posterColumn">
#     <span data-value="1" name="rk">
#     </span>
#     <span data-value="6.9" name="ir">
#     </span>
#     <span data-value="1.684368E12" name="us">
#     </span>
#     <span data-value="35090" name="nv">
#     </span>
#     <span data-value="-4.1" name="ur">
#     </span>
#     <a href="/title/tt1462764/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_1">
#      <img alt="Indiana Jones and the Dial of Destiny" height="67" src="https://m.media-amazon.com/images/M/MV5BZDQxMTY3NTAtMzYwYi00Y2U3LThkYmQtOTljY2I4ZmJiZGIzXkEyXkFqcGdeQXVyMTU1NzY5NTky._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt1462764/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_1" title="James Mangold (dir.), Harrison Ford, Phoebe Waller-Bridge">
#      Indiana Jones and the Dial of Destiny
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      1
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       10)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.9 based on 35,090 user ratings">
#      6.9
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt1462764 pending" data-titleid="tt1462764">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1462764">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="2" name="rk">
#     </span>
#     <span data-value="6.8" name="ir">
#     </span>
#     <span data-value="1.6867872E12" name="us">
#     </span>
#     <span data-value="13079" name="nv">
#     </span>
#     <span data-value="-4.2" name="ur">
#     </span>
#     <a href="/title/tt15671028/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_2">
#      <img alt="No Hard Feelings" height="67" src="https://m.media-amazon.com/images/M/MV5BMjg3N2M3OWUtZGQ3NC00OGI1LTllZDUtMTdiYWQxMTk0YTg2XkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt15671028/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_2" title="Gene Stupnitsky (dir.), Jennifer Lawrence, Andrew Barth Feldman">
#      No Hard Feelings
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      2
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       2)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.8 based on 13,079 user ratings">
#      6.8
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt15671028 pending" data-titleid="tt15671028">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt15671028">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="3" name="rk">
#     </span>
#     <span data-value="7.1" name="ir">
#     </span>
#     <span data-value="1.6848E12" name="us">
#     </span>
#     <span data-value="23081" name="nv">
#     </span>
#     <span data-value="-3.9000000000000004" name="ur">
#     </span>
#     <a href="/title/tt14230388/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_3">
#      <img alt="Asteroid City" height="67" src="https://m.media-amazon.com/images/M/MV5BNDJmMzY0ZGUtYWE1My00OWViLTg1NTctOWMwZWJlNDQzNGRiXkEyXkFqcGdeQXVyMjkwOTAyMDU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt14230388/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_3" title="Wes Anderson (dir.), Jason Schwartzman, Scarlett Johansson">
#      Asteroid City
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      3
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       2)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.1 based on 23,081 user ratings">
#      7.1
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt14230388 pending" data-titleid="tt14230388">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt14230388">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="4" name="rk">
#     </span>
#     <span data-value="7.2" name="ir">
#     </span>
#     <span data-value="1.6867008E12" name="us">
#     </span>
#     <span data-value="79545" name="nv">
#     </span>
#     <span data-value="-3.8" name="ur">
#     </span>
#     <a href="/title/tt0439572/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_4">
#      <img alt="The Flash" height="67" src="https://m.media-amazon.com/images/M/MV5BZWE2ZWE5MDQtMTJlZi00MTVjLTkxOTgtNmNiYjg2NDIxN2NhXkEyXkFqcGdeQXVyMTUzMTg2ODkz._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt0439572/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_4" title="Andy Muschietti (dir.), Ezra Miller, Michael Keaton">
#      The Flash
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      4
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       3)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.2 based on 79,545 user ratings">
#      7.2
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt0439572 pending" data-titleid="tt0439572">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0439572">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="5" name="rk">
#     </span>
#     <span data-value="8.9" name="ir">
#     </span>
#     <span data-value="1.6854912E12" name="us">
#     </span>
#     <span data-value="166663" name="nv">
#     </span>
#     <span data-value="-2.0999999999999996" name="ur">
#     </span>
#     <a href="/title/tt9362722/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_5">
#      <img alt="Spider-Man: Across the Spider-Verse" height="67" src="https://m.media-amazon.com/images/M/MV5BMzI0NmVkMjEtYmY4MS00ZDMxLTlkZmEtMzU4MDQxYTMzMjU2XkEyXkFqcGdeQXVyMzQ0MzA0NTM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt9362722/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_5" title="Joaquim Dos Santos (dir.), Shameik Moore, Hailee Steinfeld">
#      Spider-Man: Across the Spider-Verse
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      5
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       2)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="8.9 based on 166,663 user ratings">
#      8.9
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt9362722 pending" data-titleid="tt9362722">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt9362722">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="6" name="rk">
#     </span>
#     <span data-value="7.1" name="ir">
#     </span>
#     <span data-value="1.6866144E12" name="us">
#     </span>
#     <span data-value="79146" name="nv">
#     </span>
#     <span data-value="-3.9000000000000004" name="ur">
#     </span>
#     <a href="/title/tt12263384/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_6">
#      <img alt="Extraction II" height="67" src="https://m.media-amazon.com/images/M/MV5BZjg5MTM4N2QtN2RlMS00NzBlLTg3NDktM2ExZDNmMmExMGU3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt12263384/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_6" title="Sam Hargrave (dir.), Chris Hemsworth, Golshifteh Farahani">
#      Extraction II
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      6
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       4)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.1 based on 79,146 user ratings">
#      7.1
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt12263384 pending" data-titleid="tt12263384">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt12263384">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="7" name="rk">
#     </span>
#     <span data-value="0.0" name="ir">
#     </span>
#     <span data-value="1.6982784E12" name="us">
#     </span>
#     <span data-value="0" name="nv">
#     </span>
#     <span data-value="-11.0" name="ur">
#     </span>
#     <a href="/title/tt4589218/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_7">
#      <img alt="Five Nights at Freddy's" height="67" src="https://m.media-amazon.com/images/M/MV5BNWI3ZmY4NmItMGQ4My00ODJlLWJlNTktYjk2NzRkODU3YTNlXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt4589218/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_7" title="Emma Tammi (dir.), Mary Stuart Masterson, Josh Hutcherson">
#      Five Nights at Freddy's
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      7
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       79)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt4589218 pending" data-titleid="tt4589218">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt4589218">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="8" name="rk">
#     </span>
#     <span data-value="0.0" name="ir">
#     </span>
#     <span data-value="1.6888608E12" name="us">
#     </span>
#     <span data-value="0" name="nv">
#     </span>
#     <span data-value="-11.0" name="ur">
#     </span>
#     <a href="/title/tt1517268/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_8">
#      <img alt="Barbie" height="67" src="https://m.media-amazon.com/images/M/MV5BMjFlMDA2ZmUtYjE2OC00ZmYzLTg3MDYtODY4MGU3NzRhMzNhXkEyXkFqcGdeQXVyMTUzOTcyODA5._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt1517268/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_8" title="Greta Gerwig (dir.), Margot Robbie, Kingsley Ben-Adir">
#      Barbie
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      8
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       10)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt1517268 pending" data-titleid="tt1517268">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1517268">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="9" name="rk">
#     </span>
#     <span data-value="0.0" name="ir">
#     </span>
#     <span data-value="1.6897248E12" name="us">
#     </span>
#     <span data-value="0" name="nv">
#     </span>
#     <span data-value="-11.0" name="ur">
#     </span>
#     <a href="/title/tt15398776/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_9">
#      <img alt="Oppenheimer" height="67" src="https://m.media-amazon.com/images/M/MV5BMGIwMjY4ZTItOTZmNC00OTg0LWJlZDQtMGFmZTZhMGVhMDRkXkEyXkFqcGdeQXVyMTUzOTcyODA5._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt15398776/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_9" title="Christopher Nolan (dir.), Cillian Murphy, Emily Blunt">
#      Oppenheimer
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      9
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       6)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt15398776 pending" data-titleid="tt15398776">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt15398776">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="10" name="rk">
#     </span>
#     <span data-value="7.9" name="ir">
#     </span>
#     <span data-value="8.783424E11" name="us">
#     </span>
#     <span data-value="1227037" name="nv">
#     </span>
#     <span data-value="-3.0999999999999996" name="ur">
#     </span>
#     <a href="/title/tt0120338/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_10">
#      <img alt="Titanic" height="67" src="https://m.media-amazon.com/images/M/MV5BMDdmZGU3NDQtY2E5My00ZTliLWIzOTUtMTY4ZGI1YjdiNjk3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt0120338/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_10" title="James Cameron (dir.), Leonardo DiCaprio, Kate Winslet">
#      Titanic
#     </a>
#     <span class="secondaryInfo">
#      (1997)
#     </span>
#     <div class="velocity">
#      10
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       15)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.9 based on 1,227,037 user ratings">
#      7.9
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt0120338 pending" data-titleid="tt0120338">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120338">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="11" name="rk">
#     </span>
#     <span data-value="6.7" name="ir">
#     </span>
#     <span data-value="1.6788384E12" name="us">
#     </span>
#     <span data-value="90075" name="nv">
#     </span>
#     <span data-value="-4.3" name="ur">
#     </span>
#     <a href="/title/tt13345606/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_11">
#      <img alt="Evil Dead Rise" height="67" src="https://m.media-amazon.com/images/M/MV5BMmZiN2VmMjktZDE5OC00ZWRmLWFlMmEtYWViMTY4NjM3ZmNkXkEyXkFqcGdeQXVyMTI2MTc2ODM3._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt13345606/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_11" title="Lee Cronin (dir.), Mirabai Pease, Richard Crouchley">
#      Evil Dead Rise
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      11
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       20)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.7 based on 90,075 user ratings">
#      6.7
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt13345606 pending" data-titleid="tt13345606">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt13345606">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="12" name="rk">
#     </span>
#     <span data-value="7.1" name="ir">
#     </span>
#     <span data-value="1.6851456E12" name="us">
#     </span>
#     <span data-value="15313" name="nv">
#     </span>
#     <span data-value="-3.9000000000000004" name="ur">
#     </span>
#     <a href="/title/tt15789038/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_12">
#      <img alt="Elemental" height="67" src="https://m.media-amazon.com/images/M/MV5BZjYxYWVjMDMtZGRjZS00ZDE4LTk0OWUtMjUyOTI4MmYxNjgwXkEyXkFqcGdeQXVyMTUzMTg2ODkz._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt15789038/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_12" title="Peter Sohn (dir.), Leah Lewis, Mamoudou Athie">
#      Elemental
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      12
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       5)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.1 based on 15,313 user ratings">
#      7.1
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt15789038 pending" data-titleid="tt15789038">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt15789038">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="13" name="rk">
#     </span>
#     <span data-value="7.6" name="ir">
#     </span>
#     <span data-value="1.6702848E12" name="us">
#     </span>
#     <span data-value="424036" name="nv">
#     </span>
#     <span data-value="-3.4000000000000004" name="ur">
#     </span>
#     <a href="/title/tt1630029/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_13">
#      <img alt="Avatar: The Way of Water" height="67" src="https://m.media-amazon.com/images/M/MV5BYjhiNjBlODctY2ZiOC00YjVlLWFlNzAtNTVhNzM1YjI1NzMxXkEyXkFqcGdeQXVyMjQxNTE1MDA@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt1630029/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_13" title="James Cameron (dir.), Sam Worthington, Zoe Saldana">
#      Avatar: The Way of Water
#     </a>
#     <span class="secondaryInfo">
#      (2022)
#     </span>
#     <div class="velocity">
#      13
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       4)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.6 based on 424,036 user ratings">
#      7.6
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt1630029 pending" data-titleid="tt1630029">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1630029">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="14" name="rk">
#     </span>
#     <span data-value="6.3" name="ir">
#     </span>
#     <span data-value="1.683504E12" name="us">
#     </span>
#     <span data-value="8764" name="nv">
#     </span>
#     <span data-value="-4.7" name="ur">
#     </span>
#     <a href="/title/tt21909764/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_14">
#      <img alt="My Fault" height="67" src="https://m.media-amazon.com/images/M/MV5BOTEyN2NiZTUtOTE5Zi00M2U5LWI4NzktODkwNDFkMDA2ZTQ0XkEyXkFqcGdeQXVyMTM5NDQ2NjMw._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt21909764/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_14" title="Domingo González (dir.), Nicole Wallace, Gabriel Guevara">
#      My Fault
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      14
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       1)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.3 based on 8,764 user ratings">
#      6.3
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt21909764 pending" data-titleid="tt21909764">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt21909764">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="15" name="rk">
#     </span>
#     <span data-value="6.5" name="ir">
#     </span>
#     <span data-value="1.6851456E12" name="us">
#     </span>
#     <span data-value="32919" name="nv">
#     </span>
#     <span data-value="-4.5" name="ur">
#     </span>
#     <a href="/title/tt5090568/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_15">
#      <img alt="Transformers: Rise of the Beasts" height="67" src="https://m.media-amazon.com/images/M/MV5BZTNiNDA4NmMtNTExNi00YmViLWJkMDAtMDAxNmRjY2I2NDVjXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt5090568/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_15" title="Steven Caple Jr. (dir.), Anthony Ramos, Dominique Fishback">
#      Transformers: Rise of the Beasts
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      15
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       5)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.5 based on 32,919 user ratings">
#      6.5
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt5090568 pending" data-titleid="tt5090568">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt5090568">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="16" name="rk">
#     </span>
#     <span data-value="6.8" name="ir">
#     </span>
#     <span data-value="1.5876864E12" name="us">
#     </span>
#     <span data-value="235434" name="nv">
#     </span>
#     <span data-value="-4.2" name="ur">
#     </span>
#     <a href="/title/tt8936646/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_16">
#      <img alt="Extraction" height="67" src="https://m.media-amazon.com/images/M/MV5BMDJiNzUwYzEtNmQ2Yy00NWE4LWEwNzctM2M0MjE0OGUxZTA3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt8936646/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_16" title="Sam Hargrave (dir.), Chris Hemsworth, Bryon Lerum">
#      Extraction
#     </a>
#     <span class="secondaryInfo">
#      (2020)
#     </span>
#     <div class="velocity">
#      16
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       8)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.8 based on 235,434 user ratings">
#      6.8
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt8936646 pending" data-titleid="tt8936646">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt8936646">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="17" name="rk">
#     </span>
#     <span data-value="7.2" name="ir">
#     </span>
#     <span data-value="1.683504E12" name="us">
#     </span>
#     <span data-value="91219" name="nv">
#     </span>
#     <span data-value="-3.8" name="ur">
#     </span>
#     <a href="/title/tt5971474/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_17">
#      <img alt="The Little Mermaid" height="67" src="https://m.media-amazon.com/images/M/MV5BYTUxYjczMWUtYzlkZC00NTcwLWE3ODQtN2I2YTIxOTU0ZTljXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt5971474/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_17" title="Rob Marshall (dir.), Halle Bailey, Jonah Hauer-King">
#      The Little Mermaid
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      17
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       5)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.2 based on 91,219 user ratings">
#      7.2
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt5971474 pending" data-titleid="tt5971474">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt5971474">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="18" name="rk">
#     </span>
#     <span data-value="7.9" name="ir">
#     </span>
#     <span data-value="1.6786656E12" name="us">
#     </span>
#     <span data-value="229862" name="nv">
#     </span>
#     <span data-value="-3.0999999999999996" name="ur">
#     </span>
#     <a href="/title/tt10366206/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_18">
#      <img alt="John Wick: Chapter 4" height="67" src="https://m.media-amazon.com/images/M/MV5BMDExZGMyOTMtMDgyYi00NGIwLWJhMTEtOTdkZGFjNmZiMTEwXkEyXkFqcGdeQXVyMjM4NTM5NDY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt10366206/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_18" title="Chad Stahelski (dir.), Keanu Reeves, Laurence Fishburne">
#      John Wick: Chapter 4
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      18
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       2)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.9 based on 229,862 user ratings">
#      7.9
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt10366206 pending" data-titleid="tt10366206">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
# ...
#     </span>
#     <span data-value="1.6743456E12" name="us">
#     </span>
#     <span data-value="3469" name="nv">
#     </span>
#     <span data-value="-4.2" name="ur">
#     </span>
#     <a href="/title/tt15771916/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_95">
#      <img alt="You Hurt My Feelings" height="67" src="https://m.media-amazon.com/images/M/MV5BMWNiYzEzNDUtZjA3MS00NGVlLTg1MjMtZGFjN2E0YmQxYWIzXkEyXkFqcGdeQXVyMTUzMTg2ODkz._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt15771916/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_95" title="Nicole Holofcener (dir.), Julia Louis-Dreyfus, Tobias Menzies">
#      You Hurt My Feelings
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      95
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       14)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="6.8 based on 3,469 user ratings">
#      6.8
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt15771916 pending" data-titleid="tt15771916">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt15771916">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="96" name="rk">
#     </span>
#     <span data-value="7.3" name="ir">
#     </span>
#     <span data-value="1.6581024E12" name="us">
#     </span>
#     <span data-value="367807" name="nv">
#     </span>
#     <span data-value="-3.7" name="ur">
#     </span>
#     <a href="/title/tt12593682/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_96">
#      <img alt="Bullet Train" height="67" src="https://m.media-amazon.com/images/M/MV5BMDU2ZmM2OTYtNzIxYy00NjM5LTliNGQtN2JmOWQzYTBmZWUzXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt12593682/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_96" title="David Leitch (dir.), Brad Pitt, Joey King">
#      Bullet Train
#     </a>
#     <span class="secondaryInfo">
#      (2022)
#     </span>
#     <div class="velocity">
#      96
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       12)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.3 based on 367,807 user ratings">
#      7.3
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt12593682 pending" data-titleid="tt12593682">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt12593682">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="97" name="rk">
#     </span>
#     <span data-value="8.2" name="ir">
#     </span>
#     <span data-value="1.3865472E12" name="us">
#     </span>
#     <span data-value="1472901" name="nv">
#     </span>
#     <span data-value="-2.8000000000000007" name="ur">
#     </span>
#     <a href="/title/tt0993846/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_97">
#      <img alt="The Wolf of Wall Street" height="67" src="https://m.media-amazon.com/images/M/MV5BMjIxMjgxNTk0MF5BMl5BanBnXkFtZTgwNjIyOTg2MDE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt0993846/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_97" title="Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill">
#      The Wolf of Wall Street
#     </a>
#     <span class="secondaryInfo">
#      (2013)
#     </span>
#     <div class="velocity">
#      97
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       8)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="8.2 based on 1,472,901 user ratings">
#      8.2
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt0993846 pending" data-titleid="tt0993846">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0993846">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="98" name="rk">
#     </span>
#     <span data-value="8.2" name="ir">
#     </span>
#     <span data-value="1.6393536E12" name="us">
#     </span>
#     <span data-value="808759" name="nv">
#     </span>
#     <span data-value="-2.8000000000000007" name="ur">
#     </span>
#     <a href="/title/tt10872600/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_98">
#      <img alt="Spider-Man: No Way Home" height="67" src="https://m.media-amazon.com/images/M/MV5BZWMyYzFjYTYtNTRjYi00OGExLWE2YzgtOGRmYjAxZTU3NzBiXkEyXkFqcGdeQXVyMzQ0MzA0NTM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt10872600/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_98" title="Jon Watts (dir.), Tom Holland, Zendaya">
#      Spider-Man: No Way Home
#     </a>
#     <span class="secondaryInfo">
#      (2021)
#     </span>
#     <div class="velocity">
#      98
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       28)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="8.2 based on 808,759 user ratings">
#      8.2
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt10872600 pending" data-titleid="tt10872600">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt10872600">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="99" name="rk">
#     </span>
#     <span data-value="7.6" name="ir">
#     </span>
#     <span data-value="1.5583968E12" name="us">
#     </span>
#     <span data-value="783406" name="nv">
#     </span>
#     <span data-value="-3.4000000000000004" name="ur">
#     </span>
#     <a href="/title/tt7131622/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_99">
#      <img alt="Once Upon a Time in Hollywood" height="67" src="https://m.media-amazon.com/images/M/MV5BOTg4ZTNkZmUtMzNlZi00YmFjLTk1MmUtNWQwNTM0YjcyNTNkXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt7131622/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_99" title="Quentin Tarantino (dir.), Leonardo DiCaprio, Brad Pitt">
#      Once Upon a Time in Hollywood
#     </a>
#     <span class="secondaryInfo">
#      (2019)
#     </span>
#     <div class="velocity">
#      99
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter up">
#       </span>
#       13)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="7.6 based on 783,406 user ratings">
#      7.6
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt7131622 pending" data-titleid="tt7131622">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7131622">
#     </div>
#    </td>
#   </tr>
#   <tr>
#    <td class="posterColumn">
#     <span data-value="100" name="rk">
#     </span>
#     <span data-value="5.8" name="ir">
#     </span>
#     <span data-value="1.6820352E12" name="us">
#     </span>
#     <span data-value="45659" name="nv">
#     </span>
#     <span data-value="-5.2" name="ur">
#     </span>
#     <a href="/title/tt15326988/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_100">
#      <img alt="Ghosted" height="67" src="https://m.media-amazon.com/images/M/MV5BNGMzYWZlYmYtNTcyMC00ZGVjLThjN2ItMjY4MjkwN2NlMjYwXkEyXkFqcGdeQXVyOTU0NjY1MDM@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#     </a>
#    </td>
#    <td class="titleColumn">
#     <a href="/title/tt15326988/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=e9101d6a-9cbe-4310-a9f9-38e3776597d5&amp;pf_rd_r=20E3T5ED5BJ2CG8E8DG1&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=moviemeter&amp;ref_=chtmvm_tt_100" title="Dexter Fletcher (dir.), Chris Evans, Ana de Armas">
#      Ghosted
#     </a>
#     <span class="secondaryInfo">
#      (2023)
#     </span>
#     <div class="velocity">
#      100
#      <span class="secondaryInfo">
#       (
#       <span class="global-sprite titlemeter down">
#       </span>
#       3)
#      </span>
#     </div>
#    </td>
#    <td class="ratingColumn imdbRating">
#     <strong title="5.8 based on 45,659 user ratings">
#      5.8
#     </strong>
#    </td>
#    <td class="ratingColumn">
#     <div class="seen-widget seen-widget-tt15326988 pending" data-titleid="tt15326988">
#      <div class="boundary">
#       <div class="popover">
#        <span class="delete">
#        </span>
#        <ol>
#         <li>
#          1
#          <li>
#           2
#           <li>
#            3
#            <li>
#             4
#             <li>
#              5
#              <li>
#               6
#               <li>
#                7
#                <li>
#                 8
#                 <li>
#                  9
#                  <li>
#                   10
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="inline">
#       <div class="pending">
#       </div>
#       <div class="unseeable">
#        NOT YET RELEASED
#       </div>
#       <div class="unseen">
#       </div>
#       <div class="rating">
#       </div>
#       <div class="seen">
#        Seen
#       </div>
#      </div>
#     </div>
#    </td>
#    <td class="watchlistColumn">
#     <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt15326988">
#     </div>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
# if cells don't a unique identifier
# imdb_table_div = soup.find('div',class_='lister')
# imdb_table = imdb_table_div.find('table')
# titleColumn = imdb_table.find_all('td')

# %%
base_url = 'https://www.imdb.com'

# %%
# get list of links
titleColumn = soup.find_all('td','titleColumn')
# titleColumn.find('a')
links = [base_url + t.a.get('href') for t in titleColumn]

# %%
# grab cast from each movie's link
# directors_list = []
# writers_list = []
stars_list = []
for link in links[:2]:
    # print(link)
    request = requests.get(link,headers={'User-Agent': 'Mozilla/5.0'}) # get the HTML from the url
    soup = BeautifulSoup(request.content,'html.parser')
    stars_label = soup.find(string="Stars").parent
    star_elts = stars_label.next_sibling.find_all('li')
    # print(star_elts)
    # .find_all('a')
    stars = [s.text for s in star_elts]
    # print(stars)
    stars_list.append(stars)
stars_list
# exercise: grab directors and writers as well
# Out:
# [['Harrison Ford', 'Phoebe Waller-Bridge', 'Antonio Banderas'],
#  ['Jennifer Lawrence', 'Andrew Barth Feldman', 'Laura Benanti']]
